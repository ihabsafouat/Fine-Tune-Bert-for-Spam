# %%
import pandas as pd
import torch
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from torch.utils.data import Dataset
from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    Trainer,
    TrainingArguments,
)

# %%
train_df = pd.read_parquet("train.parquet")
test_df = pd.read_parquet("test.parquet")

# %%
enc = {'not_spam': 0, 'spam': 1}
train_df['label'] = train_df['label'].map(enc)
test_df['label'] = test_df['label'].map(enc)

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
def tokenize_texts(texts, labels):
    tokens = tokenizer(
        list(texts),
        padding="max_length",
        truncation=True,
        max_length=128,
        return_tensors="pt"
    )
    tokens["labels"] = torch.tensor(labels)
    return tokens

# %%
class SpamDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __getitem__(self, idx):
        return {key: val[idx] for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = logits.argmax(axis=1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average="binary")
    acc = accuracy_score(labels, preds)
    return {"accuracy": acc, "precision": precision, "recall": recall, "f1": f1}

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
results = []
best_f1 = 0.0
best_fold = 0

# %%
for fold, (train_idx, val_idx) in enumerate(kfold.split(train_df['text'], train_df['label'])):
    print(f"\n=== Fold {fold+1}/5 ===")

    train_texts = train_df.iloc[train_idx]['text'].values
    train_labels = train_df.iloc[train_idx]['label'].values
    val_texts = train_df.iloc[val_idx]['text'].values
    val_labels = train_df.iloc[val_idx]['label'].values

    train_encodings = tokenize_texts(train_texts, train_labels)
    val_encodings = tokenize_texts(val_texts, val_labels)

    train_dataset = SpamDataset(train_encodings)
    val_dataset = SpamDataset(val_encodings)

    model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)

    training_args = TrainingArguments(
        output_dir=f"./results_fold_{fold}",
        num_train_epochs=5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=64,
        learning_rate=1e-5,
        eval_strategy="epoch",
        save_strategy="epoch",
        save_total_limit=1,
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        logging_dir=f"./logs_fold_{fold}",
        logging_steps=50,
        report_to="none"
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=compute_metrics,
    )

    trainer.train()
    eval_results = trainer.evaluate()
    results.append(eval_results)

    # Save best model based on F1
    if eval_results["eval_f1"] > best_f1:
        best_f1 = eval_results["eval_f1"]
        best_fold = fold
        model.save_pretrained(f"./best_model")
        tokenizer.save_pretrained(f"./best_model")

# ========== Step 6: Evaluate Best Model on Test Set ==========
print(f"\nBest model found at fold {best_fold+1} with F1 = {best_f1:.4f}")
print("Evaluating on test set...")
# Out:
# === Fold 1/5 ===
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2045' max='2045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2045/2045 15:58, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000900</td>
#       <td>0.001383</td>
#       <td>0.999388</td>
#       <td>1.000000</td>
#       <td>0.998788</td>
#       <td>0.999394</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000300</td>
#       <td>0.000276</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000200</td>
#       <td>0.000398</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000100</td>
#       <td>0.000085</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000100</td>
#       <td>0.000068</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 00:10]
#     </div>
# === Fold 2/5 ===
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2045' max='2045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2045/2045 15:45, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000900</td>
#       <td>0.008751</td>
#       <td>0.998777</td>
#       <td>1.000000</td>
#       <td>0.997576</td>
#       <td>0.998786</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000200</td>
#       <td>0.011126</td>
#       <td>0.998165</td>
#       <td>1.000000</td>
#       <td>0.996364</td>
#       <td>0.998179</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000100</td>
#       <td>0.006107</td>
#       <td>0.998165</td>
#       <td>0.998786</td>
#       <td>0.997576</td>
#       <td>0.998181</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000100</td>
#       <td>0.006287</td>
#       <td>0.998777</td>
#       <td>1.000000</td>
#       <td>0.997576</td>
#       <td>0.998786</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000100</td>
#       <td>0.006509</td>
#       <td>0.998777</td>
#       <td>1.000000</td>
#       <td>0.997576</td>
#       <td>0.998786</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 00:10]
#     </div>
# === Fold 3/5 ===
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2045' max='2045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2045/2045 16:35, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.023200</td>
#       <td>0.001159</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.001200</td>
#       <td>0.008173</td>
#       <td>0.998165</td>
#       <td>0.996377</td>
#       <td>1.000000</td>
#       <td>0.998185</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000100</td>
#       <td>0.002090</td>
#       <td>0.999388</td>
#       <td>0.998789</td>
#       <td>1.000000</td>
#       <td>0.999394</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000100</td>
#       <td>0.002795</td>
#       <td>0.999388</td>
#       <td>0.998789</td>
#       <td>1.000000</td>
#       <td>0.999394</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000100</td>
#       <td>0.002870</td>
#       <td>0.999388</td>
#       <td>0.998789</td>
#       <td>1.000000</td>
#       <td>0.999394</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 00:10]
#     </div>
# === Fold 4/5 ===
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2045' max='2045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2045/2045 16:33, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.010400</td>
#       <td>0.010306</td>
#       <td>0.998165</td>
#       <td>0.997579</td>
#       <td>0.998788</td>
#       <td>0.998183</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.008900</td>
#       <td>0.005890</td>
#       <td>0.998777</td>
#       <td>0.998788</td>
#       <td>0.998788</td>
#       <td>0.998788</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.003400</td>
#       <td>0.008558</td>
#       <td>0.998165</td>
#       <td>0.996377</td>
#       <td>1.000000</td>
#       <td>0.998185</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000100</td>
#       <td>0.005214</td>
#       <td>0.999388</td>
#       <td>0.998789</td>
#       <td>1.000000</td>
#       <td>0.999394</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000100</td>
#       <td>0.006557</td>
#       <td>0.998165</td>
#       <td>0.998786</td>
#       <td>0.997576</td>
#       <td>0.998181</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 00:10]
#     </div>
# === Fold 5/5 ===
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='2045' max='2045' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2045/2045 15:37, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.008800</td>
#       <td>0.003482</td>
#       <td>0.998777</td>
#       <td>1.000000</td>
#       <td>0.997576</td>
#       <td>0.998786</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.009600</td>
#       <td>0.002468</td>
#       <td>0.999388</td>
#       <td>1.000000</td>
#       <td>0.998788</td>
#       <td>0.999394</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001100</td>
#       <td>0.003781</td>
#       <td>0.999388</td>
#       <td>1.000000</td>
#       <td>0.998788</td>
#       <td>0.999394</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000100</td>
#       <td>0.004232</td>
#       <td>0.999388</td>
#       <td>1.000000</td>
#       <td>0.998788</td>
#       <td>0.999394</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000100</td>
#       <td>0.004308</td>
#       <td>0.999388</td>
#       <td>1.000000</td>
#       <td>0.998788</td>
#       <td>0.999394</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='26' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26/26 00:10]
#     </div>
# Best model found at fold 1 with F1 = 1.0000
# Evaluating on test set...

# %%
test_encodings = tokenize_texts(test_df['text'].values, test_df['label'].values)
test_dataset = SpamDataset(test_encodings)

best_model = BertForSequenceClassification.from_pretrained("./best_model")
trainer = Trainer(
    model=best_model,
    compute_metrics=compute_metrics,
    args=TrainingArguments(
        output_dir="./no_log",
        report_to="none",
    )
)

test_results = trainer.evaluate(test_dataset)
print("Test set results:")
print(test_results)
# Out:
#     <div>
#
#       <progress value='341' max='341' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [341/341 00:19]
#     </div>
# Test set results:
# {'eval_loss': 0.011253364384174347, 'eval_model_preparation_time': 0.0029, 'eval_accuracy': 0.9974311926605505, 'eval_precision': 0.9978165938864629, 'eval_recall': 0.9970909090909091, 'eval_f1': 0.9974536194979993, 'eval_runtime': 19.1848, 'eval_samples_per_second': 142.04, 'eval_steps_per_second': 17.775}

# %%
from sklearn.metrics import confusion_matrix, classification_report

predictions = trainer.predict(test_dataset)
y_pred = predictions.predictions.argmax(axis=1)
y_true = test_df['label'].values

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
# Out:
# [[1347    3]
#  [   4 1371]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1350
#            1       1.00      1.00      1.00      1375
#
#     accuracy                           1.00      2725
#    macro avg       1.00      1.00      1.00      2725
# weighted avg       1.00      1.00      1.00      2725

# %%
# !zip -r content.zip /content/
from google.colab import files
files.download("content.zip")
# Out:
# updating: content/ (stored 0%)
# updating: content/.config/ (stored 0%)
# updating: content/.config/active_config (stored 0%)
# updating: content/.config/logs/ (stored 0%)
# updating: content/.config/logs/2025.04.30/ (stored 0%)
# updating: content/.config/logs/2025.04.30/13.36.50.566118.log (deflated 58%)
# updating: content/.config/logs/2025.04.30/13.36.58.979052.log (deflated 86%)
# updating: content/.config/logs/2025.04.30/13.36.29.848398.log (deflated 93%)
# updating: content/.config/logs/2025.04.30/13.37.09.510583.log (deflated 56%)
# updating: content/.config/logs/2025.04.30/13.37.00.207659.log (deflated 58%)
# updating: content/.config/logs/2025.04.30/13.37.08.828246.log (deflated 57%)
# updating: content/.config/.last_opt_in_prompt.yaml (stored 0%)
# updating: content/.config/gce (stored 0%)
# updating: content/.config/.last_update_check.json (deflated 23%)
# updating: content/.config/.last_survey_prompt.yaml (stored 0%)
# updating: content/.config/config_sentinel (stored 0%)
# updating: content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
# updating: content/.config/default_configs.db (deflated 98%)
# updating: content/.config/configurations/ (stored 0%)
# updating: content/.config/configurations/config_default (deflated 15%)
# updating: content/train.parquet (deflated 13%)
# updating: content/results_fold_4/ (stored 0%)
# updating: content/results_fold_4/checkpoint-818/ (stored 0%)
# updating: content/results_fold_4/checkpoint-818/config.json (deflated 49%)
# updating: content/results_fold_4/checkpoint-818/training_args.bin (deflated 52%)
# updating: content/results_fold_4/checkpoint-818/trainer_state.json (deflated 71%)
# updating: content/results_fold_4/checkpoint-818/model.safetensors (deflated 7%)
# updating: content/results_fold_4/checkpoint-818/optimizer.pt (deflated 20%)
# updating: content/results_fold_4/checkpoint-818/rng_state.pth (deflated 25%)
# updating: content/results_fold_4/checkpoint-818/scheduler.pt (deflated 55%)
# updating: content/results_fold_2/ (stored 0%)
# updating: content/results_fold_2/checkpoint-409/ (stored 0%)
# updating: content/results_fold_2/checkpoint-409/config.json (deflated 49%)
# updating: content/results_fold_2/checkpoint-409/training_args.bin (deflated 52%)
# updating: content/results_fold_2/checkpoint-409/trainer_state.json (deflated 66%)
# updating: content/results_fold_2/checkpoint-409/model.safetensors (deflated 7%)
# updating: content/results_fold_2/checkpoint-409/optimizer.pt (deflated 20%)
# updating: content/results_fold_2/checkpoint-409/rng_state.pth (deflated 25%)
# updating: content/results_fold_2/checkpoint-409/scheduler.pt (deflated 56%)
# updating: content/results_fold_1/ (stored 0%)
# updating: content/results_fold_1/checkpoint-409/ (stored 0%)
# updating: content/results_fold_1/checkpoint-409/config.json (deflated 49%)
# updating: content/results_fold_1/checkpoint-409/training_args.bin (deflated 51%)
# updating: content/results_fold_1/checkpoint-409/trainer_state.json (deflated 66%)
# updating: content/results_fold_1/checkpoint-409/model.safetensors (deflated 7%)
# updating: content/results_fold_1/checkpoint-409/optimizer.pt (deflated 20%)
# updating: content/results_fold_1/checkpoint-409/rng_state.pth (deflated 25%)
# updating: content/results_fold_1/checkpoint-409/scheduler.pt (deflated 56%)
# updating: content/results_fold_0/ (stored 0%)
# updating: content/results_fold_0/checkpoint-818/ (stored 0%)
# updating: content/results_fold_0/checkpoint-818/config.json (deflated 49%)
# updating: content/results_fold_0/checkpoint-818/training_args.bin (deflated 52%)
# updating: content/results_fold_0/checkpoint-818/trainer_state.json (deflated 71%)
# updating: content/results_fold_0/checkpoint-818/model.safetensors (deflated 7%)
# updating: content/results_fold_0/checkpoint-818/optimizer.pt (deflated 20%)
# updating: content/results_fold_0/checkpoint-818/rng_state.pth (deflated 25%)
# updating: content/results_fold_0/checkpoint-818/scheduler.pt (deflated 55%)
# updating: content/test.parquet (deflated 13%)
# updating: content/no_log/ (stored 0%)
# updating: content/results_fold_3/ (stored 0%)
# updating: content/results_fold_3/checkpoint-1636/ (stored 0%)
# updating: content/results_fold_3/checkpoint-1636/config.json (deflated 49%)
# updating: content/results_fold_3/checkpoint-1636/training_args.bin (deflated 52%)
# updating: content/results_fold_3/checkpoint-1636/trainer_state.json (deflated 76%)
# updating: content/results_fold_3/checkpoint-1636/model.safetensors (deflated 7%)
# updating: content/results_fold_3/checkpoint-1636/optimizer.pt (deflated 20%)
# updating: content/results_fold_3/checkpoint-1636/rng_state.pth (deflated 25%)
# updating: content/results_fold_3/checkpoint-1636/scheduler.pt (deflated 55%)
# updating: content/best_model/ (stored 0%)
# updating: content/best_model/config.json (deflated 49%)
# updating: content/best_model/tokenizer_config.json (deflated 75%)
# updating: content/best_model/model.safetensors (deflated 7%)
# updating: content/best_model/vocab.txt (deflated 53%)
# updating: content/best_model/special_tokens_map.json (deflated 42%)
# updating: content/sample_data/ (stored 0%)
# updating: content/sample_data/anscombe.json (deflated 83%)
# updating: content/sample_data/README.md (deflated 39%)
# updating: content/sample_data/mnist_test.csv (deflated 88%)
# updating: content/sample_data/california_housing_train.csv (deflated 79%)
# updating: content/sample_data/mnist_train_small.csv (deflated 88%)
# updating: content/sample_data/california_housing_test.csv (deflated 76%)
